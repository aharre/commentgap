# %%
import regex as re

# Define the feature and policy names
featnames = {'lexdiv': 'Lexical Diversity',
            'sentclass': 'Sentiment',
            'sim': 'Topical Similarity',
            'smog': 'Readability'}
polnames = {'policy_chron': 'Chronological',
            'policy_least-neg-abs': 'Rev. Downvotes',
            'policy_neg-abs': 'Downvotes',
            'policy_pos-abs': 'Upvotes',
            'policy_pos-rel': 'Relative Votes',
            'policy_rev-chron': 'Rev. Chronological',
            'policy_random': 'Random',
            'policy_pin-pred-lr': 'Pred. Editors\' Picks (LR)',
            'policy_pin-pred-rf': 'Pred. Editors\' Picks (RF)',
            'policy_pred-nb': 'Pred. Upvotes (NBR)',
            'policy_pred-rf': 'Pred. Upvotes (RF)',
            'replies_rh': 'Replies Hidden',
            'replies_rt': 'Reply Trees Shown',
            'replies_rl': 'Replies Loose',
            'replies hidden': 'Replies Hidden',
            'reply trees': 'Reply Trees Shown',
            'replies loose': 'Replies Loose',
            'pinned': 'Editors\' Picks Pinned',
            'not_pinned': 'Editors\' Picks Not Pinned'}
titles = {'10': 'First 10 comments','N': 'Full Comment Discussion'}
polnames = {k.replace('-', '.'): v for k, v in polnames.items()}

def read_model_output(filename):
    """Reads the model output file and extracts relevant data."""
    main_data = []
    replyh_data = []
    replyt_data = []
    pin_data = []
    model_stats = {}
    with open(filename, 'r') as file:
        lines = file.readlines()
        start_reading = False
        read_vals = False
        for line in lines:
            if line.strip().startswith("AIC"):
                read_vals = True
                continue
            if read_vals:
                # Read model statistics line which typically starts after the main table
                stats_parts = line.split()
                model_stats['AIC'] = stats_parts[0]
                model_stats['BIC'] = stats_parts[1]
                model_stats['logLik'] = stats_parts[2]
                read_vals = False
                continue
            if line.strip().startswith("Dispersion"):
                model_stats['dispersion'] = line.split()[-1]
                continue
            if line.strip().startswith("Conditional model:"):
                start_reading = True
                continue
            if start_reading:
                if line.strip() == "---":
                    break
                parts = line.split()
                if len(parts) >= 5 and parts[0] != '---':
                    variable = ' '.join(parts[:1])
                    estimate = parts[1]
                    std_error = parts[2]
                    z_value = parts[3]
                    p_value = ' '.join(parts[4:-1])
                    stars = parts[-1]
                    if '*' in stars:
                        # apply scientific notatrion formatting
                        p_value = re.sub(r'e(-?\d+)', r'\\times 10 ^ {\1}', p_value)
                        p_value = '$' + p_value + '$' + stars
                    elif stars[-1] == '.':
                        p_value = '$' + p_value + '$' + stars
                    else:
                        p_value = '$' + stars[:-1] + '$' + '.'
                    if ':replies_rh' in variable:
                        replyh_data.append((variable, estimate, std_error, z_value, p_value))
                    elif ':replies_rt' in variable:
                        replyt_data.append((variable, estimate, std_error, z_value, p_value))
                    elif ':pinned' in variable:
                        pin_data.append((variable, estimate, std_error, z_value, p_value))
                    else:
                        main_data.append((variable, estimate, std_error, z_value, p_value))
    data = main_data + ['Reply Structure Interactions'] + replyh_data + replyt_data + ['Editors\' Picks Interactions'] + pin_data
        
    # Assume sample size is located somewhere in the text, adapt this line if necessary
    model_stats['sample_size'] = "172,590"  # Update this if you know where to find it or set manually
    return data[1:], model_stats

def format_latex_table(data, model_stats, featname, n):
    """Formats the data into a LaTeX table and returns it as a string."""
    fname = "$\\text{FORUM}^{\\text{%s}}_{\\text{%s}}$" %(featnames[featname], n)
    preamble = ["\\begin{table*}[htbp]\n", "\\centering\n"]

    pre_table = ["\\begin{tabular}{c|c|c|c|c|c}\n",
                 "Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\\phi$) \\\\ \\hline \n",
                f"{fname} & {model_stats['sample_size']} & {model_stats['AIC']} & {model_stats['BIC']} & {model_stats['logLik']} & {model_stats['dispersion']} \\\\\n",
                "\\end{tabular}\n\n\\ \n\n\\ \n\n",]
    
    main_table = ["\\begin{tabular}{l|r|r|r|c}\n",
                "Variable & Estimate & Std. Error & $z$-value & $p$-value \\\\\n",
                "\\hline\n",
                "---\\textit{Main Effects} & & & & \\\\\n"]
    for d in data:
        try:
            var, est, err, z, p = d
            formatted_line = f"{var} & {est} & {err} & {z} & {p} \\\\\n"
        except ValueError:
            formatted_line = "---\\textit{%s} & & & & \\\\\n" %d
        main_table.append(formatted_line.replace(':', ' : '))
    main_table.append("\\end{tabular}\n")

    postamble = ["\\caption{Regression output for modelling FORUM score for %s over the %s (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}\n" %(featnames[featname], titles[n].lower()),
                 "\\label{tab:results-%s_%s}\n" %(featname, n),
                 "\\end{table*}\n"]

    table = ''.join(preamble + pre_table + main_table + postamble)
    for k, v in polnames.items():
        table = table.replace(k, v)
    return table

# %%
featname = 'lexdiv'
n = '10'

for featname in featnames:
    for n in ['10', 'N']:
        data, model_stats = read_model_output(f'data/model_summaries/{featname}_{n}.txt')
        latex_table_string = format_latex_table(data, model_stats, featname, n)
        print(latex_table_string)
# Out:
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Lexical Diversity}}_{\text{10}}$ & 172,590 & -294457.9 & -294005.3 & 147273.9 & 21.1 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & -0.020218 & 0.006797 & -2.97 & $0.002933$** \\
# Downvotes & 0.251277 & 0.009645 & 26.05 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & 0.157662 & 0.009627 & 16.38 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes & 0.392939 & 0.009682 & 40.58 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes & 0.378964 & 0.009677 & 39.16 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological & 0.046104 & 0.009614 & 4.80 & $1.62\times 10 ^ {-06}$*** \\
# Chronological & -0.134353 & 0.009617 & -13.97 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) & 0.892746 & 0.009992 & 89.35 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & 0.635259 & 0.009800 & 64.82 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) & 1.137757 & 0.010252 & 110.98 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & 0.605743 & 0.009781 & 61.93 & $< 2\times 10 ^ {-16}$*** \\
# Replies Hidden & 0.156649 & 0.008348 & 18.76 & $< 2\times 10 ^ {-16}$*** \\
# Reply Trees Shown & -0.028078 & 0.008327 & -3.37 & $0.000747$*** \\
# Editors' Picks Pinned & 0.178654 & 0.006812 & 26.23 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.093737 & 0.011854 & -7.91 & $2.63\times 10 ^ {-15}$*** \\
# Rev. Downvotes : Replies Hidden & -0.109090 & 0.011813 & -9.23 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Replies Hidden & -0.130381 & 0.011891 & -10.96 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Replies Hidden & -0.128417 & 0.011885 & -10.80 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Replies Hidden & 0.014685 & 0.011810 & 1.24 & $0.21369$. \\
# Chronological : Replies Hidden & -0.076149 & 0.011794 & -6.46 & $1.07\times 10 ^ {-10}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.167553 & 0.012287 & -13.64 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & -0.157184 & 0.012038 & -13.06 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.155879 & 0.012636 & -12.34 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & -0.157145 & 0.012013 & -13.08 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes : Reply Trees Shown & -0.199822 & 0.011800 & -16.93 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Reply Trees Shown & -0.417645 & 0.011806 & -35.38 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Reply Trees Shown & -0.242221 & 0.011824 & -20.49 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Reply Trees Shown & -0.235774 & 0.011821 & -19.95 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Reply Trees Shown & 0.048062 & 0.011780 & 4.08 & $4.51\times 10 ^ {-05}$*** \\
# Chronological : Reply Trees Shown & -0.059439 & 0.011784 & -5.04 & $4.56\times 10 ^ {-07}$*** \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.531801 & 0.012058 & -44.10 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.347677 & 0.011916 & -29.18 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.638380 & 0.012269 & -52.03 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.370295 & 0.011896 & -31.13 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & -0.064906 & 0.009658 & -6.72 & $1.81\times 10 ^ {-11}$*** \\
# Rev. Downvotes : Editors' Picks Pinned & -0.086389 & 0.009648 & -8.95 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Editors' Picks Pinned & -0.150033 & 0.009679 & -15.50 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Editors' Picks Pinned & -0.145686 & 0.009675 & -15.06 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Editors' Picks Pinned & -0.042845 & 0.009638 & -4.45 & $8.76\times 10 ^ {-06}$*** \\
# Chronological : Editors' Picks Pinned & 0.073402 & 0.009630 & 7.62 & $2.50\times 10 ^ {-14}$*** \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.187825 & 0.009899 & -18.97 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & -0.177347 & 0.009765 & -18.16 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & -0.180838 & 0.010094 & -17.92 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & -0.178419 & 0.009747 & -18.30 & $< 2\times 10 ^ {-16}$*** \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Lexical Diversity over the first 10 comments (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-lexdiv_10}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Lexical Diversity}}_{\text{N}}$ & 172,590 & -525667.9 & -525215.3 & 262878.9 & 86 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & 0.0005774 & 0.0034257 & 0.17 & $0.86615$. \\
# Downvotes & 0.2368417 & 0.0048593 & 48.74 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & -0.0917531 & 0.0048464 & -18.93 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes & 0.3226846 & 0.0048714 & 66.24 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes & 0.1938004 & 0.0048547 & 39.92 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological & 0.1107323 & 0.0048487 & 22.84 & $< 2\times 10 ^ {-16}$*** \\
# Chronological & -0.0988691 & 0.0048469 & -20.40 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) & 0.8449817 & 0.0050313 & 167.94 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & 0.3788403 & 0.0048821 & 77.60 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) & 1.1137706 & 0.0051797 & 215.03 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & 0.4315085 & 0.0048937 & 88.18 & $< 2\times 10 ^ {-16}$*** \\
# Replies Hidden & 0.2214753 & 0.0042071 & 52.64 & $< 2\times 10 ^ {-16}$*** \\
# Reply Trees Shown & 0.0164575 & 0.0041935 & 3.92 & $8.69\times 10 ^ {-05}$*** \\
# Editors' Picks Pinned & 0.0179051 & 0.0034314 & 5.22 & $1.81\times 10 ^ {-07}$*** \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.2014852 & 0.0059630 & -33.79 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Replies Hidden & 0.0856568 & 0.0059501 & 14.40 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Replies Hidden & -0.2709995 & 0.0059729 & -45.37 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Replies Hidden & -0.1529210 & 0.0059598 & -25.66 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Replies Hidden & -0.0893330 & 0.0059532 & -15.01 & $< 2\times 10 ^ {-16}$*** \\
# Chronological : Replies Hidden & 0.0767333 & 0.0059494 & 12.90 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.6670469 & 0.0061033 & -109.29 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & -0.2877491 & 0.0059840 & -48.09 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.8757124 & 0.0062189 & -140.81 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & -0.3149773 & 0.0059949 & -52.54 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes : Reply Trees Shown & -0.1631771 & 0.0059427 & -27.46 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Reply Trees Shown & 0.0082522 & 0.0059325 & 1.39 & $0.16421$. \\
# Upvotes : Reply Trees Shown & -0.2292530 & 0.0059519 & -38.52 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Reply Trees Shown & -0.1297546 & 0.0059387 & -21.85 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Reply Trees Shown & -0.0194237 & 0.0059349 & -3.27 & $0.001065$** \\
# Chronological : Reply Trees Shown & -0.0121248 & 0.0059331 & -2.04 & $0.040994$* \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.5097535 & 0.0060875 & -83.74 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.2317682 & 0.0059616 & -38.88 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.4983709 & 0.0062437 & -79.82 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.2311469 & 0.0059731 & -38.70 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & -0.0089561 & 0.0048607 & -1.84 & $0.065396$. \\
# Rev. Downvotes : Editors' Picks Pinned & -0.0112725 & 0.0048532 & -2.32 & $0.020196$* \\
# Upvotes : Editors' Picks Pinned & -0.0150768 & 0.0048664 & -3.10 & $0.001947$** \\
# Relative Votes : Editors' Picks Pinned & -0.0129635 & 0.0048588 & -2.67 & $0.007629$** \\
# Rev. Chronological : Editors' Picks Pinned & -0.0133658 & 0.0048558 & -2.75 & $0.005913$** \\
# Chronological : Editors' Picks Pinned & 0.0017821 & 0.0048532 & 0.37 & $0.71346$. \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.0187702 & 0.0049435 & -3.80 & $0.000147$*** \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & -0.0177157 & 0.0048738 & -3.63 & $0.000278$*** \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & -0.0181823 & 0.0050254 & -3.62 & $0.000297$*** \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & -0.0178872 & 0.0048817 & -3.66 & $0.000248$*** \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Lexical Diversity over the full comment discussion (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-lexdiv_N}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Sentiment}}_{\text{10}}$ & 172,590 & -118548.2 & -118095.6 & 59319.1 & 7.07 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & -0.211938 & 0.011227 & -18.877 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes & -0.182987 & 0.015942 & -11.478 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & 0.003350 & 0.015874 & 0.211 & $0.83285$. \\
# Upvotes & -0.085737 & 0.015901 & -5.392 & $6.97\times 10 ^ {-08}$*** \\
# Relative Votes & -0.069399 & 0.015895 & -4.366 & $1.26\times 10 ^ {-05}$*** \\
# Rev. Chronological & -0.043243 & 0.015886 & -2.722 & $0.006486$** \\
# Chronological & 0.046545 & 0.015866 & 2.934 & $0.003350$** \\
# Pred. Editors' Picks (LR) & 0.170644 & 0.015846 & 10.769 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & -0.073782 & 0.015898 & -4.641 & $3.47\times 10 ^ {-06}$*** \\
# Pred. Upvotes (NBR) & 0.222217 & 0.015846 & 14.024 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & -0.167594 & 0.015940 & -10.514 & $< 2\times 10 ^ {-16}$*** \\
# Replies Hidden & -0.008198 & 0.013753 & -0.596 & $0.55112$. \\
# Reply Trees Shown & 0.021554 & 0.013746 & 1.568 & $0.11687$. \\
# Editors' Picks Pinned & -0.018131 & 0.011226 & -1.615 & $0.10628$. \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.002864 & 0.019530 & -0.147 & $0.88341$. \\
# Rev. Downvotes : Replies Hidden & 0.030936 & 0.019444 & 1.591 & $0.11161$. \\
# Upvotes : Replies Hidden & 0.019111 & 0.019477 & 0.981 & $0.32650$. \\
# Relative Votes : Replies Hidden & 0.018884 & 0.019471 & 0.970 & $0.33211$. \\
# Rev. Chronological : Replies Hidden & 0.043290 & 0.019456 & 2.225 & $0.026079$* \\
# Chronological : Replies Hidden & -0.003492 & 0.019436 & -0.180 & $0.85743$. \\
# Pred. Editors' Picks (LR) : Replies Hidden & 0.001515 & 0.019409 & 0.078 & $0.93777$. \\
# Pred. Editors' Picks (RF) : Replies Hidden & 0.008611 & 0.019475 & 0.442 & $0.65838$. \\
# Pred. Upvotes (NBR) : Replies Hidden & 0.005305 & 0.019407 & 0.273 & $0.78458$. \\
# Pred. Upvotes (RF) : Replies Hidden & 0.008379 & 0.019528 & 0.429 & $0.66786$. \\
# Downvotes : Reply Trees Shown & 0.047471 & 0.019501 & 2.434 & $0.014922$* \\
# Rev. Downvotes : Reply Trees Shown & 0.089774 & 0.019428 & 4.621 & $3.82\times 10 ^ {-06}$*** \\
# Upvotes : Reply Trees Shown & 0.052538 & 0.019459 & 2.700 & $0.006935$** \\
# Relative Votes : Reply Trees Shown & 0.041556 & 0.019455 & 2.136 & $0.032674$* \\
# Rev. Chronological : Reply Trees Shown & 0.024085 & 0.019449 & 1.238 & $0.21556$. \\
# Chronological : Reply Trees Shown & -0.029249 & 0.019430 & -1.505 & $0.13223$. \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.105066 & 0.019410 & -5.413 & $6.20\times 10 ^ {-08}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & 0.034785 & 0.019458 & 1.788 & $0.073827$. \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.187792 & 0.019412 & -9.674 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & 0.069399 & 0.019497 & 3.559 & $0.000372$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & 0.056801 & 0.015932 & 3.565 & $0.000363$*** \\
# Rev. Downvotes : Editors' Picks Pinned & -0.006336 & 0.015866 & -0.399 & $0.68964$. \\
# Upvotes : Editors' Picks Pinned & 0.024844 & 0.015893 & 1.563 & $0.11800$. \\
# Relative Votes : Editors' Picks Pinned & 0.021145 & 0.015889 & 1.331 & $0.18325$. \\
# Rev. Chronological : Editors' Picks Pinned & 0.014338 & 0.015880 & 0.903 & $0.36659$. \\
# Chronological : Editors' Picks Pinned & -0.010082 & 0.015867 & -0.635 & $0.52519$. \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & 0.007819 & 0.015848 & 0.493 & $0.62177$. \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & 0.020213 & 0.015892 & 1.272 & $0.20342$. \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & 0.016902 & 0.015849 & 1.066 & $0.28622$. \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & 0.018410 & 0.015928 & 1.156 & $0.24774$. \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Sentiment over the first 10 comments (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-sentclass_10}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Sentiment}}_{\text{N}}$ & 172,590 & -562730.0 & -562277.3 & 281410.0 & 110 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & 0.0020643 & 0.0030296 & 0.68 & $0.49562$. \\
# Downvotes & -0.0761012 & 0.0042859 & -17.76 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & 0.0595160 & 0.0042855 & 13.89 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes & -0.0235559 & 0.0042847 & -5.50 & $3.85\times 10 ^ {-08}$*** \\
# Relative Votes & 0.0175394 & 0.0042847 & 4.09 & $4.25\times 10 ^ {-05}$*** \\
# Rev. Chronological & -0.0372936 & 0.0042848 & -8.70 & $< 2\times 10 ^ {-16}$*** \\
# Chronological & 0.0334810 & 0.0042848 & 7.81 & $5.55\times 10 ^ {-15}$*** \\
# Pred. Editors' Picks (LR) & 0.3009409 & 0.0043052 & 69.90 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & -0.0320140 & 0.0042848 & -7.47 & $7.93\times 10 ^ {-14}$*** \\
# Pred. Upvotes (NBR) & 0.3232004 & 0.0043083 & 75.02 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & -0.0312853 & 0.0042849 & -7.30 & $2.85\times 10 ^ {-13}$*** \\
# Replies Hidden & -0.0176764 & 0.0037106 & -4.76 & $1.90\times 10 ^ {-06}$*** \\
# Reply Trees Shown & 0.0001565 & 0.0037105 & 0.04 & $0.96635$. \\
# Editors' Picks Pinned & -0.0002214 & 0.0030297 & -0.07 & $0.94175$. \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & 0.0523575 & 0.0052486 & 9.98 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Replies Hidden & -0.0465315 & 0.0052481 & -8.87 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Replies Hidden & 0.0115702 & 0.0052477 & 2.20 & $0.027468$* \\
# Relative Votes : Replies Hidden & -0.0225468 & 0.0052476 & -4.30 & $1.73\times 10 ^ {-05}$*** \\
# Rev. Chronological : Replies Hidden & 0.0329959 & 0.0052478 & 6.29 & $3.22\times 10 ^ {-10}$*** \\
# Chronological : Replies Hidden & -0.0268875 & 0.0052477 & -5.12 & $3.00\times 10 ^ {-07}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.2455792 & 0.0052626 & -46.67 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & 0.0188573 & 0.0052478 & 3.59 & $0.000326$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.2539435 & 0.0052651 & -48.23 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & 0.0023869 & 0.0052480 & 0.45 & $0.64924$. \\
# Downvotes : Reply Trees Shown & 0.0084119 & 0.0052490 & 1.60 & $0.10902$. \\
# Rev. Downvotes : Reply Trees Shown & -0.0008919 & 0.0052486 & -0.17 & $0.86506$. \\
# Upvotes : Reply Trees Shown & 0.0057371 & 0.0052476 & 1.09 & $0.27426$. \\
# Relative Votes : Reply Trees Shown & -0.0014895 & 0.0052476 & -0.28 & $0.77653$. \\
# Rev. Chronological : Reply Trees Shown & 0.0171600 & 0.0052477 & 3.27 & $0.001076$** \\
# Chronological : Reply Trees Shown & -0.0211160 & 0.0052477 & -4.02 & $5.73\times 10 ^ {-05}$*** \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.1617756 & 0.0052655 & -30.72 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.0053127 & 0.0052478 & -1.01 & $0.31136$. \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.1974848 & 0.0052673 & -37.49 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.0272092 & 0.0052481 & -5.18 & $2.17\times 10 ^ {-07}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & 0.0044032 & 0.0042855 & 1.03 & $0.30419$. \\
# Rev. Downvotes : Editors' Picks Pinned & -0.0027284 & 0.0042852 & -0.64 & $0.52431$. \\
# Upvotes : Editors' Picks Pinned & 0.0005469 & 0.0042847 & 0.13 & $0.89842$. \\
# Relative Votes : Editors' Picks Pinned & -0.0001582 & 0.0042847 & -0.04 & $0.97054$. \\
# Rev. Chronological : Editors' Picks Pinned & 0.0011699 & 0.0042847 & 0.27 & $0.78483$. \\
# Chronological : Editors' Picks Pinned & -0.0003008 & 0.0042847 & -0.07 & $0.94403$. \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.0007342 & 0.0042944 & -0.17 & $0.86424$. \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & 0.0003275 & 0.0042848 & 0.08 & $0.93908$. \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & 0.0002617 & 0.0042955 & 0.06 & $0.95142$. \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & 0.0002430 & 0.0042851 & 0.06 & $0.95477$. \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Sentiment over the full comment discussion (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-sentclass_N}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Topical Similarity}}_{\text{10}}$ & 172,590 & -157843.7 & -157391.0 & 78966.8 & 9.25 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & -0.390273 & 0.010025 & -38.93 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes & 0.254969 & 0.014135 & 18.04 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & 0.287709 & 0.014126 & 20.37 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes & 0.470852 & 0.014126 & 33.33 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes & 0.470805 & 0.014126 & 33.33 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological & -0.124790 & 0.014211 & -8.78 & $< 2\times 10 ^ {-16}$*** \\
# Chronological & 0.199354 & 0.014135 & 14.10 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) & 0.874724 & 0.014261 & 61.34 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & 0.613618 & 0.014151 & 43.36 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) & 0.637248 & 0.014158 & 45.01 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & 0.547419 & 0.014140 & 38.71 & $< 2\times 10 ^ {-16}$*** \\
# Replies Hidden & 0.357335 & 0.012239 & 29.20 & $< 2\times 10 ^ {-16}$*** \\
# Reply Trees Shown & 0.049546 & 0.012286 & 4.03 & $5.52\times 10 ^ {-05}$*** \\
# Editors' Picks Pinned & 0.111290 & 0.010003 & 11.13 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.233601 & 0.017267 & -13.53 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Replies Hidden & -0.219288 & 0.017265 & -12.70 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Replies Hidden & -0.306388 & 0.017272 & -17.74 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Replies Hidden & -0.300676 & 0.017272 & -17.41 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Replies Hidden & 0.158602 & 0.017347 & 9.14 & $< 2\times 10 ^ {-16}$*** \\
# Chronological : Replies Hidden & -0.230692 & 0.017270 & -13.36 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.359021 & 0.017450 & -20.57 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & -0.353993 & 0.017303 & -20.46 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.350296 & 0.017313 & -20.23 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & -0.357455 & 0.017281 & -20.68 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes : Reply Trees Shown & -0.403135 & 0.017382 & -23.19 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Reply Trees Shown & -0.323085 & 0.017350 & -18.62 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Reply Trees Shown & -0.422198 & 0.017332 & -24.36 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Reply Trees Shown & -0.406124 & 0.017328 & -23.44 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Reply Trees Shown & 0.314167 & 0.017385 & 18.07 & $< 2\times 10 ^ {-16}$*** \\
# Chronological : Reply Trees Shown & -0.260514 & 0.017353 & -15.01 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.590532 & 0.017392 & -33.95 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.499152 & 0.017337 & -28.79 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.535026 & 0.017344 & -30.85 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.582617 & 0.017364 & -33.55 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & -0.026034 & 0.014147 & -1.84 & $0.0657$. \\
# Rev. Downvotes : Editors' Picks Pinned & -0.069902 & 0.014131 & -4.95 & $7.55\times 10 ^ {-07}$*** \\
# Upvotes : Editors' Picks Pinned & -0.098226 & 0.014125 & -6.95 & $3.54\times 10 ^ {-12}$*** \\
# Relative Votes : Editors' Picks Pinned & -0.099751 & 0.014123 & -7.06 & $1.63\times 10 ^ {-12}$*** \\
# Rev. Chronological : Editors' Picks Pinned & 0.007007 & 0.014151 & 0.50 & $0.620$. \\
# Chronological : Editors' Picks Pinned & 0.005395 & 0.014133 & 0.38 & $0.702$. \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.122752 & 0.014203 & -8.64 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & -0.110964 & 0.014135 & -7.85 & $4.14\times 10 ^ {-15}$*** \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & -0.110745 & 0.014141 & -7.83 & $4.83\times 10 ^ {-15}$*** \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & -0.110834 & 0.014143 & -7.84 & $4.63\times 10 ^ {-15}$*** \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Topical Similarity over the first 10 comments (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-sim_10}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Topical Similarity}}_{\text{N}}$ & 172,590 & -497667.2 & -497214.6 & 248878.6 & 71.8 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & 0.004910 & 0.003752 & 1.31 & $0.19$. \\
# Downvotes & 0.211018 & 0.005319 & 39.67 & $<2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & -0.070602 & 0.005308 & -13.30 & $<2\times 10 ^ {-16}$*** \\
# Upvotes & 0.430184 & 0.005358 & 80.29 & $<2\times 10 ^ {-16}$*** \\
# Relative Votes & 0.279981 & 0.005329 & 52.54 & $<2\times 10 ^ {-16}$*** \\
# Rev. Chronological & -0.131090 & 0.005310 & -24.69 & $<2\times 10 ^ {-16}$*** \\
# Chronological & 0.134726 & 0.005312 & 25.36 & $<2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) & 1.041703 & 0.005618 & 185.43 & $<2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & 0.456956 & 0.005366 & 85.16 & $<2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) & 0.899535 & 0.005534 & 162.54 & $<2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & 0.674689 & 0.005435 & 124.15 & $<2\times 10 ^ {-16}$*** \\
# Replies Hidden & 0.485731 & 0.004653 & 104.39 & $<2\times 10 ^ {-16}$*** \\
# Reply Trees Shown & 0.002554 & 0.004584 & 0.56 & $0.57$. \\
# Editors' Picks Pinned & 0.006041 & 0.003779 & 1.60 & $0.11$. \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.210681 & 0.006590 & -31.97 & $<2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Replies Hidden & 0.074832 & 0.006582 & 11.37 & $<2\times 10 ^ {-16}$*** \\
# Upvotes : Replies Hidden & -0.404426 & 0.006622 & -61.07 & $<2\times 10 ^ {-16}$*** \\
# Relative Votes : Replies Hidden & -0.253736 & 0.006601 & -38.44 & $<2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Replies Hidden & 0.130437 & 0.006584 & 19.81 & $<2\times 10 ^ {-16}$*** \\
# Chronological : Replies Hidden & -0.136330 & 0.006584 & -20.71 & $<2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.889178 & 0.006840 & -130.00 & $<2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & -0.408881 & 0.006631 & -61.66 & $<2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.822935 & 0.006762 & -121.69 & $<2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & -0.625033 & 0.006682 & -93.54 & $<2\times 10 ^ {-16}$*** \\
# Downvotes : Reply Trees Shown & -0.351359 & 0.006496 & -54.09 & $<2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Reply Trees Shown & 0.236047 & 0.006490 & 36.37 & $<2\times 10 ^ {-16}$*** \\
# Upvotes : Reply Trees Shown & -0.482741 & 0.006521 & -74.02 & $<2\times 10 ^ {-16}$*** \\
# Relative Votes : Reply Trees Shown & -0.215653 & 0.006500 & -33.18 & $<2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Reply Trees Shown & 0.229344 & 0.006488 & 35.35 & $<2\times 10 ^ {-16}$*** \\
# Chronological : Reply Trees Shown & -0.220434 & 0.006488 & -33.97 & $<2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.800340 & 0.006725 & -119.02 & $<2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.581102 & 0.006528 & -89.01 & $<2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.909599 & 0.006652 & -136.73 & $<2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.868351 & 0.006584 & -131.90 & $<2\times 10 ^ {-16}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & 0.001673 & 0.005352 & 0.31 & $0.75$. \\
# Rev. Downvotes : Editors' Picks Pinned & -0.002663 & 0.005348 & -0.50 & $0.61$. \\
# Upvotes : Editors' Picks Pinned & -0.004709 & 0.005368 & -0.88 & $0.38$. \\
# Relative Votes : Editors' Picks Pinned & -0.005953 & 0.005356 & -1.11 & $0.26$. \\
# Rev. Chronological : Editors' Picks Pinned & 0.007474 & 0.005348 & 1.40 & $0.16$. \\
# Chronological : Editors' Picks Pinned & -0.001001 & 0.005347 & -0.19 & $0.85$. \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.007634 & 0.005481 & -1.39 & $0.16$. \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & -0.005946 & 0.005374 & -1.11 & $0.26$. \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & -0.005935 & 0.005437 & -1.09 & $0.27$. \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & -0.005980 & 0.005402 & -1.11 & $0.26$. \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Topical Similarity over the full comment discussion (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-sim_N}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Readability}}_{\text{10}}$ & 172,590 & -322895.1 & -322442.4 & 161492.5 & 26.3 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & -0.067242 & 0.006112 & -11.00 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes & 0.149740 & 0.008648 & 17.31 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & 0.084929 & 0.008646 & 9.82 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes & 0.269428 & 0.008662 & 31.10 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes & 0.263339 & 0.008661 & 30.40 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological & -0.026242 & 0.008644 & -3.04 & $0.0024$** \\
# Chronological & -0.087797 & 0.008651 & -10.15 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) & 0.469145 & 0.008717 & 53.82 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & 0.377357 & 0.008687 & 43.44 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) & 0.603267 & 0.008777 & 68.74 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & 0.393052 & 0.008692 & 45.22 & $< 2\times 10 ^ {-16}$*** \\
# Replies Hidden & 0.104849 & 0.007489 & 14.00 & $< 2\times 10 ^ {-16}$*** \\
# Reply Trees Shown & -0.014587 & 0.007486 & -1.95 & $0.0514$. \\
# Editors' Picks Pinned & 0.102014 & 0.006114 & 16.68 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.060801 & 0.010600 & -5.74 & $9.69\times 10 ^ {-09}$*** \\
# Rev. Downvotes : Replies Hidden & -0.067165 & 0.010590 & -6.34 & $2.26\times 10 ^ {-10}$*** \\
# Upvotes : Replies Hidden & -0.090254 & 0.010616 & -8.50 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Replies Hidden & -0.088956 & 0.010614 & -8.38 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Replies Hidden & 0.045541 & 0.010591 & 4.30 & $1.71\times 10 ^ {-05}$*** \\
# Chronological : Replies Hidden & -0.046641 & 0.010592 & -4.40 & $1.07\times 10 ^ {-05}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.107702 & 0.010685 & -10.08 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & -0.106675 & 0.010646 & -10.02 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.103286 & 0.010764 & -9.60 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & -0.105053 & 0.010652 & -9.86 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes : Reply Trees Shown & -0.141599 & 0.010591 & -13.37 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Reply Trees Shown & -0.256352 & 0.010603 & -24.18 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Reply Trees Shown & -0.167023 & 0.010599 & -15.76 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Reply Trees Shown & -0.165443 & 0.010598 & -15.61 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Reply Trees Shown & 0.072082 & 0.010587 & 6.81 & $9.88\times 10 ^ {-12}$*** \\
# Chronological : Reply Trees Shown & -0.045381 & 0.010596 & -4.28 & $1.85\times 10 ^ {-05}$*** \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.273858 & 0.010639 & -25.74 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.217473 & 0.010617 & -20.48 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.319109 & 0.010686 & -29.86 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.238666 & 0.010620 & -22.47 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & -0.035151 & 0.008652 & -4.06 & $4.85\times 10 ^ {-05}$*** \\
# Rev. Downvotes : Editors' Picks Pinned & -0.051846 & 0.008655 & -5.99 & $2.09\times 10 ^ {-09}$*** \\
# Upvotes : Editors' Picks Pinned & -0.090237 & 0.008660 & -10.42 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Editors' Picks Pinned & -0.088041 & 0.008659 & -10.17 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Editors' Picks Pinned & -0.020668 & 0.008647 & -2.39 & $0.0168$* \\
# Chronological : Editors' Picks Pinned & 0.057327 & 0.008652 & 6.63 & $3.44\times 10 ^ {-11}$*** \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.105297 & 0.008699 & -12.10 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & -0.101236 & 0.008677 & -11.67 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & -0.103372 & 0.008746 & -11.82 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & -0.101895 & 0.008680 & -11.74 & $< 2\times 10 ^ {-16}$*** \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Readability over the first 10 comments (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-smog_10}
# \end{table*}
#
# \begin{table*}[htbp]
# \centering
# \begin{tabular}{c|c|c|c|c|c}
# Outcome & Sample Size & AIC & BIC & Log-Likelihood & Dispersion ($\phi$) \\ \hline
# $\text{FORUM}^{\text{Readability}}_{\text{N}}$ & 172,590 & -577243.1 & -576790.5 & 288666.6 & 118 \\
# \end{tabular}
#
# \
#
# \
#
# \begin{tabular}{l|r|r|r|c}
# Variable & Estimate & Std. Error & $z$-value & $p$-value \\
# \hline
# ---\textit{Main Effects} & & & & \\
# (Intercept) & 0.002512 & 0.002926 & 0.86 & $0.3904$. \\
# Downvotes & 0.162340 & 0.004143 & 39.18 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes & -0.073586 & 0.004138 & -17.78 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes & 0.256305 & 0.004152 & 61.73 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes & 0.166135 & 0.004144 & 40.09 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological & 0.045004 & 0.004138 & 10.88 & $< 2\times 10 ^ {-16}$*** \\
# Chronological & -0.041906 & 0.004138 & -10.13 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (LR) & 0.552618 & 0.004205 & 131.41 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) & 0.261231 & 0.004153 & 62.90 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) & 0.776065 & 0.004274 & 181.57 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) & 0.370631 & 0.004168 & 88.92 & $< 2\times 10 ^ {-16}$*** \\
# Replies Hidden & 0.165792 & 0.003589 & 46.20 & $< 2\times 10 ^ {-16}$*** \\
# Reply Trees Shown & 0.008996 & 0.003582 & 2.51 & $0.01202$* \\
# Editors' Picks Pinned & 0.008194 & 0.002928 & 2.80 & $0.00514$** \\
# ---\textit{Reply Structure Interactions} & & & & \\
# Downvotes : Replies Hidden & -0.140293 & 0.005081 & -27.61 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Replies Hidden & 0.067494 & 0.005075 & 13.30 & $< 2\times 10 ^ {-16}$*** \\
# Upvotes : Replies Hidden & -0.220047 & 0.005087 & -43.25 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Replies Hidden & -0.136728 & 0.005081 & -26.91 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Replies Hidden & -0.034701 & 0.005076 & -6.84 & $8.11\times 10 ^ {-12}$*** \\
# Chronological : Replies Hidden & 0.028587 & 0.005075 & 5.63 & $1.77\times 10 ^ {-08}$*** \\
# Pred. Editors' Picks (LR) : Replies Hidden & -0.448255 & 0.005131 & -87.37 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Replies Hidden & -0.204176 & 0.005089 & -40.12 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Replies Hidden & -0.619613 & 0.005184 & -119.51 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Replies Hidden & -0.284798 & 0.005102 & -55.82 & $< 2\times 10 ^ {-16}$*** \\
# Downvotes : Reply Trees Shown & -0.123029 & 0.005071 & -24.26 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Downvotes : Reply Trees Shown & 0.029269 & 0.005067 & 5.78 & $7.61\times 10 ^ {-09}$*** \\
# Upvotes : Reply Trees Shown & -0.192881 & 0.005077 & -37.99 & $< 2\times 10 ^ {-16}$*** \\
# Relative Votes : Reply Trees Shown & -0.116625 & 0.005071 & -23.00 & $< 2\times 10 ^ {-16}$*** \\
# Rev. Chronological : Reply Trees Shown & 0.010522 & 0.005067 & 2.08 & $0.03784$* \\
# Chronological : Reply Trees Shown & -0.024438 & 0.005066 & -4.82 & $1.41\times 10 ^ {-06}$*** \\
# Pred. Editors' Picks (LR) : Reply Trees Shown & -0.355704 & 0.005121 & -69.46 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Editors' Picks (RF) : Reply Trees Shown & -0.174507 & 0.005078 & -34.36 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (NBR) : Reply Trees Shown & -0.383383 & 0.005189 & -73.89 & $< 2\times 10 ^ {-16}$*** \\
# Pred. Upvotes (RF) : Reply Trees Shown & -0.229562 & 0.005091 & -45.09 & $< 2\times 10 ^ {-16}$*** \\
# ---\textit{Editors' Picks Interactions} & & & & \\
# Downvotes : Editors' Picks Pinned & -0.003047 & 0.004144 & -0.74 & $0.4622$. \\
# Rev. Downvotes : Editors' Picks Pinned & -0.003969 & 0.004141 & -0.96 & $0.3379$. \\
# Upvotes : Editors' Picks Pinned & -0.006794 & 0.004148 & -1.64 & $0.1014$. \\
# Relative Votes : Editors' Picks Pinned & -0.005583 & 0.004145 & -1.35 & $0.1780$. \\
# Rev. Chronological : Editors' Picks Pinned & -0.004625 & 0.004142 & -1.12 & $0.2641$. \\
# Chronological : Editors' Picks Pinned & 0.002999 & 0.004141 & 0.72 & $0.4689$. \\
# Pred. Editors' Picks (LR) : Editors' Picks Pinned & -0.008483 & 0.004174 & -2.03 & $0.04214$* \\
# Pred. Editors' Picks (RF) : Editors' Picks Pinned & -0.008081 & 0.004150 & -1.95 & $0.05150$. \\
# Pred. Upvotes (NBR) : Editors' Picks Pinned & -0.008331 & 0.004212 & -1.98 & $0.04791$* \\
# Pred. Upvotes (RF) : Editors' Picks Pinned & -0.008169 & 0.004158 & -1.96 & $0.04945$* \\
# \end{tabular}
# \caption{Regression output for modelling FORUM score for Readability over the full comment discussion (***: $p<0.001$, **: $p<0.01$, *: $p<0.05$, .: $p \ge 0.05$).}
# \label{tab:results-smog_N}
# \end{table*}
